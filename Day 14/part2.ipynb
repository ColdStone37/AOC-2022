# %%
array = []

with open("input.txt", 'r') as file:
    array = file.readlines()
    
array = [[[int(c) for c in b.split(",")] for b in a.split("->")] for a in array]
print(array)
# Out:
# [[[521, 171], [525, 171]], [[497, 147], [497, 137], [497, 147], [499, 147], [499, 146], [499, 147], [501, 147], [501, 142], [501, 147], [503, 147], [503, 144], [503, 147], [505, 147], [505, 140], [505, 147]], [[465, 76], [465, 71], [465, 76], [467, 76], [467, 72], [467, 76], [469, 76], [469, 68], [469, 76], [471, 76], [471, 73], [471, 76], [473, 76], [473, 71], [473, 76], [475, 76], [475, 70], [475, 76], [477, 76], [477, 71], [477, 76], [479, 76], [479, 73], [479, 76], [481, 76], [481, 74], [481, 76], [483, 76], [483, 72], [483, 76]], [[476, 63], [476, 58], [476, 63], [478, 63], [478, 55], [478, 63], [480, 63], [480, 56], [480, 63], [482, 63], [482, 57], [482, 63], [484, 63], [484, 55], [484, 63], [486, 63], [486, 55], [486, 63]], [[503, 109], [507, 109]], [[465, 76], [465, 71], [465, 76], [467, 76], [467, 72], [467, 76], [469, 76], [469, 68], [469, 76], [471, 76], [471, 73], [471, 76], [473, 76], [473, 71], [473, 76], [475, 76], [475, 70], [475, 76], [477, 76], [477, 71], [477, 76],
# ...

# %%
minX = 1000000000
maxX = -1000000000
minY = 1000000000
maxY = -1000000000

for list in array:
    for vector in list:
        if vector[0] < minX:
            minX = vector[0]
        if vector[0] > maxX:
            maxX = vector[0]
        if vector[1] < minY:
            minY = vector[1]
        if vector[1] > maxY:
            maxY = vector[1]
print(minX,maxX,minY,maxY)

maxY += 2
minX = 500-maxY-10
maxX = 500+maxY+10
# Out:
# 465 536 12 178

# %%
Map = []
for y in range(maxY+1):
    row = []
    for x in range(maxX-minX+1):
        row.append(".")
    Map.append(row)

# %%
for list in array:
    for index in range(len(list)-1):
        vector1 = list[index]
        vector2 = list[index+1]
        if vector1[0] == vector2[0]:
            for y in range(min(vector1[1],vector2[1]),1+max(vector1[1],vector2[1])):
                Map[y][vector1[0]-minX] = "#"
        elif vector1[1] == vector2[1]:
            for x in range(min(vector1[0],vector2[0]),1+max(vector1[0],vector2[0])):
                Map[vector1[1]][x-minX] = "#"
        else:
            print("Help")

for x in range(maxX-minX+1):
    Map[len(Map)-1][x] = "#"
for row in Map:
    [print(elem,end="") for elem in row]
    print()
# Out:
# .............................................................................................................................................................................................................................................................................................................................................................................................
# .............................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
def simulateSand(x, y, Map):
    if y >= len(Map) - 1:
        return True, [-1,-1]
    if Map[y+1][x] == ".":
        return False, [x,y+1]
    if x <= 0:
        return True, [-1,-1]
    if Map[y+1][x-1] == ".":
        return False, [x-1,y+1]
    if x >= len(Map[y])-1:
        return True, [-1,-1]
    if Map[y+1][x+1] == ".":
        return False, [x+1,y+1]
    return False, [x,y]

# %%
finished = False
count = 0
while not finished:
    pos = [-1,-1]
    newPos = [500-minX,0]
    
    while not (pos == newPos or finished):
        pos = newPos
        finished, newPos = simulateSand(pos[0],pos[1],Map)
    Map[pos[1]][pos[0]] = "O"
    count += 1
    finished = Map[0][500-minX] == "O"
    if count % 1000 == 0:
        print(count)
    
for row in Map:
    [print(elem,end="") for elem in row]
    print()
    
print(count)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# ..............................................................................................................................................................................................O..............................................................................................................................................................................................
# .............................................................................................................................................................................................OOO.............................................................................................................................................................................................
# ...
